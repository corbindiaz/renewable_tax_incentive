# %%
# Define regex filter function for exact `nPage=X` match
def exact_npage_filter(n):
    return f"""
    els => els
      .map(el => el.href)
      .filter(href => /[?&]nPage={n}(?:&|$)/.test(href))
    """

# Main scraping function
async def extract_connecticut_energy_statutes():
    results = []
    async with async_playwright() as p:
        browser = await p.firefox.launch(headless=False)
        page = await browser.new_page()

        await page.goto("https://search.cga.state.ct.us/r/statute/", wait_until="domcontentloaded")

        await page.fill("input#request", "energy")
        await page.press("input#request", "Enter")
        await page.wait_for_selector("table.footable tbody tr")

        page_num = 1
        seen_pages = set()

        while True:
            print(f"[INFO] Processing page {page_num}")

            # ✅ Get all matching <td> elements and extract trimmed text
            rows = await page.query_selector_all("table.footable tbody tr td.footable-visible")
            for row in rows:
                text = (await row.inner_text()).strip()
                match = re.match(r"^(.*?\..*?\.)", text)
                if match:
                    results.append(match.group(1))

            # ✅ Look for next page link using fast JS filtering
            candidate_links = await page.eval_on_selector_all(
                "a[href*='nPage=']", exact_npage_filter(page_num + 1)
            )
            if not candidate_links:
                break

            # ✅ Navigate without waiting for domcontentloaded again
            await page.goto(candidate_links[0], wait_until="networkidle")
            page_num += 1

        await browser.close()
        return results

# This cell prepares the function but does not execute it automatically. You can run this in a Jupyter cell like:
section_titles = await extract_connecticut_energy_statutes()
print(section_titles[:5])
print(f"Total extracted titles: {len(section_titles)}")
# Out:
# [INFO] Processing page 1
# [INFO] Processing page 2
# [INFO] Processing page 3
# [INFO] Processing page 4
# [INFO] Processing page 5
# [INFO] Processing page 6
# [INFO] Processing page 7
# [INFO] Processing page 8
# [INFO] Processing page 9
# [INFO] Processing page 10
# [INFO] Processing page 11
# [INFO] Processing page 12
# [INFO] Processing page 13
# [INFO] Processing page 14
# [INFO] Processing page 15
# [INFO] Processing page 16
# [INFO] Processing page 17
# [INFO] Processing page 18
# [INFO] Processing page 19
# [INFO] Processing page 20
# [INFO] Processing page 21
# [INFO] Processing page 22
# [INFO] Processing page 23
# [INFO] Processing page 24
# [INFO] Processing page 25
# [INFO] Processing page 26
# [INFO] Processing page 27
# [INFO] Processing page 28
# [INFO] Processing page 29
# [INFO] Processing page 30
# [INFO] Processing page 31
# [INFO] Processing page 32
# [INFO] Processing page 33
# [INFO] Processing page 34
# [INFO] Processing page 35
# [INFO] Processing page 36
# ['Sec. 1-24.', 'Sec. 1-84.', 'Sec. 1-206.', 'Sec. 1-217.', 'Sec. 2-20a.']
# Total extracted titles: 1440

# %%
import asyncio
import re
from typing import Optional, Tuple, List
from playwright.async_api import async_playwright

def parse_section(section: str) -> Optional[str]:
    """
    Extract the core part from section strings like:
      'Sec. 1-24.'    -> '1-24'
      'Section 1-206' -> '1-206'
      'Sec. 16a-244b' -> '16a-244b'
    """
    pattern = r'(\d+[A-Za-z]*(?:-\d+[A-Za-z]*)*)'
    m = re.search(pattern, section)
    return m.group(1) if m else None

def normalize(sec: str) -> List:
    """Split and normalize '16a-244b' → [16, 'a', 244, 'b'] for easy comparison."""
    parts = re.split(r'([A-Za-z]+|\d+)', sec)
    return [int(p) if p.isdigit() else p for p in parts if p]

def denormalize(parts: List) -> str:
    """Re-build section string from normalized parts."""
    return ''.join(str(p) for p in parts)

def section_in_range(target: str, start: str, end: str) -> bool:
    """Return True if normalized(start) ≤ normalized(target) ≤ normalized(end)."""
    t, s, e = normalize(target), normalize(start), normalize(end)
    return s <= t <= e
async def fetch_ct_statute_text(section: str) -> Tuple[Optional[str], List[str]]:
    """
    Given 'Sec. 1-24.', finds the appropriate chapter page and scrapes the
    paragraph lines for that section (up through the <p class="source-first">).
    Returns (final_url, [lines]) or (None, []) on failure.
    """
    parsed = parse_section(section)
    if not parsed:
        print(f"[ERROR] Could not parse {section!r}.")
        return None, []

    target = denormalize(normalize(parsed))

    async with async_playwright() as p:
        browser = await p.firefox.launch(headless=True)
        page = await browser.new_page()

        # ---- 1) Top‐level TOC: find which Title contains our section ----
        await page.goto("https://www.cga.ct.gov/current/pub/titles.htm",
                        wait_until="domcontentloaded")
        top_href = None
        for row in await page.query_selector_all("table[style*='width:80%'] td.left_38pct"):
            a    = await row.query_selector("a")
            span = await row.query_selector("span.toc_rng_chaps")
            if not a or not span:
                continue
            txt = await span.inner_text()
            m   = re.search(r'\(?Secs?\. ([\d\w\-]+)\s+to\s+([\d\w\-]+)\)?', txt)
            if m and section_in_range(parsed, m.group(1), m.group(2)):
                top_href = await a.get_attribute("href")
                print(f"[MATCH] Top‐level range {m.group(1)}–{m.group(2)} → {top_href}")
                break

        if not top_href:
            print(f"[WARN] No top‐level title for {section}.")
            await browser.close()
            return None, []

        # ---- 2) Load that Title, scan its chapter links ----
        title_url = f"https://www.cga.ct.gov/current/pub/{top_href}"
        await page.goto(title_url, wait_until="domcontentloaded")

        final_url = None
    
        for td in await page.query_selector_all("td.left_40pct"):
            a    = await td.query_selector("a")
            span = await td.query_selector("span.toc_rng_secs")
            if not a or not span:
                continue
    
            # CORRECTED LINE:
            txt = (await span.inner_text()).strip()
    
            # first try “X to Y”
            m = re.search(r'\(?Secs?\. ([\d\w\-]+)\s+to\s+([\d\w\-]+)\)?', txt)
            if m:
                start, end = m.groups()
            else:
                # fallback to “Sec. Z”
                m2 = re.search(r'\(?Sec\. ([\d\w\-]+)\)?', txt)
                if m2:
                    start = end = m2.group(1)
                else:
                    continue

            print(f"[CHECK] Chapter link covers {start}–{end} for {section}.")
            if section_in_range(target, start, end):
                href      = await a.get_attribute("href")
                final_url = f"https://www.cga.ct.gov/current/pub/{href}"
                print(f"[FOUND] In‐chapter {start}–{end} → {final_url}")
                break

        if not final_url:
            print(f"[WARN] No chapter link matched {section}.")
            await browser.close()
            return title_url, []

        # ---- 3) Scrape paragraph up to and including <p class="source-first"> ----
        await page.goto(final_url, wait_until="domcontentloaded")
        print(f"[INFO] Extracting sec_{target}…")
        try:
            lines = await page.eval_on_selector(
                f"span#sec_{target}",
                """
                span => {
                  const out = [];
                  const firstP = span.closest('p');
                  if (!firstP) return out;
                  out.push(firstP.innerText.trim());
                  let p = firstP.nextElementSibling;
                  while (p) {
                    out.push(p.innerText.trim());
                    if (p.classList.contains('source-first')) break;
                    p = p.nextElementSibling;
                  }
                  return out;
                }
                """
            )
        except Exception as e:
            print(f"[ERROR] Failed to extract sec_{target}: {e}")
            lines = []

        await browser.close()
        return final_url, lines

# %%
texts = []
for section in section_titles:
    text = await fetch_ct_statute_text(section)
    texts.append(text)
# Out:
# [MATCH] Top‐level range 1-1–1-500 → title_01.htm
# [CHECK] Chapter link covers 1-1–1-3b for Sec. 1-24..
# [CHECK] Chapter link covers 1-4–1-6 for Sec. 1-24..
# [CHECK] Chapter link covers 1-7–1-21l for Sec. 1-24..
# [CHECK] Chapter link covers 1-22–1-25 for Sec. 1-24..
# [FOUND] In‐chapter 1-22–1-25 → https://www.cga.ct.gov/current/pub/chap_004.htm
# [INFO] Extracting sec_1-24…
# [MATCH] Top‐level range 1-1–1-500 → title_01.htm
# [CHECK] Chapter link covers 1-1–1-3b for Sec. 1-84..
# [CHECK] Chapter link covers 1-4–1-6 for Sec. 1-84..
# [CHECK] Chapter link covers 1-7–1-21l for Sec. 1-84..
# [CHECK] Chapter link covers 1-22–1-25 for Sec. 1-84..
# [CHECK] Chapter link covers 1-26–1-27 for Sec. 1-84..
# [CHECK] Chapter link covers 1-28–1-41 for Sec. 1-84..
# [CHECK] Chapter link covers 1-42–1-56 for Sec. 1-84..
# [CHECK] Chapter link covers 1-56a–1-56g for Sec. 1-84..
# [CHECK] Chapter link covers 1-56h–1-56q for Sec. 1-84..
# [CHECK] Chapter link covers 1-56r–1-56r for Sec. 1-84..
# [CHECK] Chapter link covers 1-57–1-65z for Sec. 1-84..
# [CHECK] Chapter link covers 1-65aa–1-65hh for Sec. 1-84..
# [CHECK] Chapter link covers 1-66–1-78 for Sec. 1-84..
# [CHECK] Chapter link covers 1-79–1-101rr for Sec. 1-84..
# [FOUND] In‐chapter 1-79–1-101rr → https://www.cga.ct.gov/current/pub/chap_010.htm
# [INFO] Extracting sec_1-84…
# [MATCH] Top‐level range 1-1–1-500 → title_01.htm
# [CHECK] Chapter link covers 1-1–1-3b for Sec. 1-206..
# [CHECK] Chapter link covers 1-4–1-6 for Sec. 1-206..
# [CHECK] Chapter link covers 1-7–1-21l for Sec. 1-206..
# [CHECK] Chapter link covers 1-22–1-25 for Sec. 1-206..
# [CHECK] Chapter link covers 1-26–1-27 for Sec. 1-206..
# [CHECK] Chapter link covers 1-28–1-41 for Sec. 1-206..
# [CHECK] Chapter link covers 1-42–1-56 for Sec. 1-206..
# [CHECK] Chapter link covers 1-56a–1-56g for Sec. 1-206..
# [CHECK] Chapter link covers 1-56h–1-56q for Sec. 1-206..
# [CHECK] Chapter link covers 1-56r–1-56r for Sec. 1-206..
# [CHECK] Chapter link covers 1-57–1-65z for Sec. 1-206..
# [CHECK] Chapter link covers 1-65aa–1-65hh for Sec. 1-206..
# [CHECK] Chapter link covers 1-66–1-78 for Sec. 1-206..
# [CHECK] Chapter link covers 1-79–1-101rr for Sec. 1-206..
# [CHECK] Chapter link covers 1-102–1-109 for Sec. 1-206..
# [CHECK] Chapter link covers 1-110–1-119 for Sec. 1-206..
# [CHECK] Chapter link covers 1-120–1-134 for Sec. 1-206..
# [CHECK] Chapter link covers 1-135–1-140 for Sec. 1-206..
# [CHECK] Chapter link covers 1-141–1-199 for Sec. 1-206..
# [CHECK] Chapter link covers 1-200–1-259 for Sec. 1-206..
# [FOUND] In‐chapter 1-200–1-259 → https://www.cga.ct.gov/current/pub/chap_014.htm
# [INFO] Extracting sec_1-206…
# [MATCH] Top‐level range 1-1–1-500 → title_01.htm
# [CHECK] Chapter link covers 1-1–1-3b for Sec. 1-217..
# [CHECK] Chapter link covers 1-4–1-6 for Sec. 1-217..
# [CHECK] Chapter link covers 1-7–1-21l for Sec. 1-217..
# [CHECK] Chapter link covers 1-22–1-25 for Sec. 1-217..
# [CHECK] Chapter link covers 1-26–1-27 for Sec. 1-217..
# [CHECK] Chapter link covers 1-28–1-41 for Sec. 1-217..
# [CHECK] Chapter link covers 1-42–1-56 for Sec. 1-217..
# [CHECK] Chapter link covers 1-56a–1-56g for Sec. 1-217..
# [CHECK] Chapter link covers 1-56h–1-56q for Sec. 1-217..
# [CHECK] Chapter link covers 1-56r–1-56r for Sec. 1-217..
# [CHECK] Chapter link covers 1-57–1-65z for Sec. 1-217..
# [CHECK] Chapter link covers 1-65aa–1-65hh for Sec. 1-217..
# [CHECK] Chapter link covers 1-66–1-78 for Sec. 1-217..
# [CHECK] Chapter link covers 1-79–1-101rr for Sec. 1-217..
# [CHECK] Chapter link covers 1-102–1-109 for Sec. 1-217..
# [CHECK] Chapter link covers 1-110–1-119 for Sec. 1-217..
# [CHECK] Chapter link covers 1-120–1-134 for Sec. 1-217..
# [CHECK] Chapter link covers 1-135–1-140 for Sec. 1-217..
# [CHECK] Chapter link covers 1-141–1-199 for Sec. 1-217..
# [CHECK] Chapter link covers 1-200–1-259 for Sec. 1-217..
# [FOUND] In‐chapter 1-200–1-259 → https://www.cga.ct.gov/current/pub/chap_014.htm
# [INFO] Extracting sec_1-217…
# [MATCH] Top‐level range 2-1–2-139 → title_02.htm
# [CHECK] Chapter link covers 2-1–2-53n for Sec. 2-20a..
# [FOUND] In‐chapter 2-1–2-53n → https://www.cga.ct.gov/current/pub/chap_016.htm
# [INFO] Extracting sec_2-20a…
# [MATCH] Top‐level range 2-1–2-139 → title_02.htm
# [CHECK] Chapter link covers 2-1–2-53n for Sec. 2-33a..
# [FOUND] In‐chapter 2-1–2-53n → https://www.cga.ct.gov/current/pub/chap_016.htm
# [INFO] Extracting sec_2-33a…
# [MATCH] Top‐level range 2-1–2-139 → title_02.htm
# [CHECK] Chapter link covers 2-1–2-53n for Sec. 2-53k..
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-7..
# [FOUND] In‐chapter 3-1–3-10f → https://www.cga.ct.gov/current/pub/chap_031.htm
# [INFO] Extracting sec_3-7…
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-20..
# [CHECK] Chapter link covers 3-11–3-76t for Sec. 3-20..
# [FOUND] In‐chapter 3-11–3-76t → https://www.cga.ct.gov/current/pub/chap_032.htm
# [INFO] Extracting sec_3-20…
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-21..
# [CHECK] Chapter link covers 3-11–3-76t for Sec. 3-21..
# [FOUND] In‐chapter 3-11–3-76t → https://www.cga.ct.gov/current/pub/chap_032.htm
# [INFO] Extracting sec_3-21…
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-22p..
# [CHECK] Chapter link covers 3-11–3-76t for Sec. 3-22p..
# [FOUND] In‐chapter 3-11–3-76t → https://www.cga.ct.gov/current/pub/chap_032.htm
# [INFO] Extracting sec_3-22p…
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-39r..
# [CHECK] Chapter link covers 3-11–3-76t for Sec. 3-39r..
# [FOUND] In‐chapter 3-11–3-76t → https://www.cga.ct.gov/current/pub/chap_032.htm
# [INFO] Extracting sec_3-39r…
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-99d..
# [CHECK] Chapter link covers 3-11–3-76t for Sec. 3-99d..
# [CHECK] Chapter link covers 3-77–3-110s for Sec. 3-99d..
# [FOUND] In‐chapter 3-77–3-110s → https://www.cga.ct.gov/current/pub/chap_033.htm
# [INFO] Extracting sec_3-99d…
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-100..
# [CHECK] Chapter link covers 3-11–3-76t for Sec. 3-100..
# [CHECK] Chapter link covers 3-77–3-110s for Sec. 3-100..
# [FOUND] In‐chapter 3-77–3-110s → https://www.cga.ct.gov/current/pub/chap_033.htm
# [INFO] Extracting sec_3-100…
# [MATCH] Top‐level range 3-1–3-131 → title_03.htm
# [CHECK] Chapter link covers 3-1–3-10f for Sec. 3-114l..
# [CHECK] Chapter link covers 3-11–3-76t for Sec. 3-114l..
# [CHECK] Chapter link covers 3-77–3-110s for Sec. 3-114l..
# [CHECK] Chapter link covers 3-111–3-123yyy for Sec. 3-114l..
# [FOUND] In‐chapter 3-111–3-123yyy → https://www.cga.ct.gov/current/pub/chap_034.htm
# [INFO] Extracting sec_3-114l…
# [MATCH] Top‐level range 4-1–4-289 → title_04.htm
# [CHECK] Chapter link covers 4-1–4-23 for Sec. 4-5..
# [FOUND] In‐chapter 4-1–4-23 → https://www.cga.ct.gov/current/pub/chap_046.htm
# [INFO] Extracting sec_4-5…
# [MATCH] Top‐level range 4-1–4-289 → title_04.htm
# [CHECK] Chapter link covers 4-1–4-23 for Sec. 4
# [INFO] Extracting sec_4-168…
# [MATCH] Top‐level range 4-1–4-289 → title_04.htm
# [CHECK] Chapter link covers 4-1–4-23 for Sec. 4-252a..
# [CHECK] Chapter link covers 4-23a–4-23p for Sec. 4-252a..
# [CHECK] Chapter link covers 4-24–4-37v for Sec. 4-252a..
# [CHECK] Chapter link covers 4-38–4-61pp for Sec. 4-252a..
# [CHECK] Chapter link covers 4-62–4-64 for Sec. 4-252a..
# [CHECK] Chapter link covers 4-65–4-124xx for Sec. 4-252a..
# [CHECK] Chapter link covers 4-125–4-137 for Sec. 4-252a..
# [CHECK] Chapter link covers 4-137a–4-137h for Sec. 4-252a..
# [CHECK] Chapter link covers 4-138–4-140 for Sec. 4-252a..
# [CHECK] Chapter link covers 4-141–4-165c for Sec. 4-252a..
# [CHECK] Chapter link covers 4-166–4-189g for Sec. 4-252a..
# [CHECK] Chapter link covers 4-189h–4-189j for Sec. 4-252a..
# [CHECK] Chapter link covers 4-190–4-204 for Sec. 4-252a..
# [CHECK] Chapter link covers 4-205–4-229 for Sec. 4-252a..
# [CHECK] Chapter link covers 4-230–4-249 for Sec. 4-252a..
# [CHECK] Chapter link covers 4-250–4-254 for Sec. 4-252a..
# [FOUND] In‐chapter 4-250–4-254 → https://www.cga.ct.gov/current/pub/chap_055c.htm
# [INFO] Extracting sec_4-252a…
# [MATCH] Top‐level range 4a-1–4a-101 → title_04a.htm
# [CHECK] Chapter link covers 4a-1–4a-18 for Sec. 4a-53..
# [CHECK] Chapter link covers 4a-19–4a-24 for Sec. 4a-53..
# [CHECK] Chapter link covers 4a-25–4a-49 for Sec. 4a-53..
# [CHECK] Chapter link covers 4a-50–4a-99 for Sec. 4a-53..
# [FOUND] In‐chapter 4a-50–4a-99 → https://www.cga.ct.gov/current/pub/chap_058.htm
# [INFO] Extracting sec_4a-53…
# [MATCH] Top‐level range 4a-1–4a-101 → title_04a.htm
# [CHECK] Chapter link covers 4a-1–4a-18 for Sec. 4a-56..
# [CHECK] Chapter link covers 4a-19–4a-24 for Sec. 4a-56..
# [CHECK] Chapter link covers 4a-25–4a-49 for Sec. 4a-56..
# [CHECK] Chapter link covers 4a-50–4a-99 for Sec. 4a-56..
# [FOUND] In‐chapter 4a-50–4a-99 → https://www.cga.ct.gov/current/pub/chap_058.htm
# [INFO] Extracting sec_4a-56…
# [MATCH] Top‐level range 4a-1–4a-101 → title_04a.htm
# [CHECK] Chapter link covers 4a-1–4a-18 for Sec. 4a-57..
# [CHECK] Chapter link covers 4a-19–4a-24 for Sec. 4a-57..
# [CHECK] Chapter link covers 4a-25–4a-49 for Sec. 4a-57..
# [CHECK] Chapter link covers 4a-50–4a-99 for Sec. 4a-57..
# [FOUND] In‐chapter 4a-50–4a-99 → https://www.cga.ct.gov/current/pub/chap_058.htm
# [INFO] Extracting sec_4a-57…
# [MATCH] Top‐level range 4a-1–4a-101 → title_04a.htm
# [CHECK] Chapter link covers 4a-1–4a-18 for Sec. 4a-67c..
# [CHECK] Chapter link covers 4a-19–4a-24 for Sec. 4a-67c..
# [CHECK] Chapter link covers 4a-25–4a-49 for Sec. 4a-67c..
# [CHECK] Chapter link covers 4a-50–4a-99 for Sec. 4a-67c..
# [FOUND] In‐chapter 4a-50–4a-99 → https://www.cga.ct.gov/current/pub/chap_058.htm
# [INFO] Extracting sec_4a-67c…
# [MATCH] Top‐level range 4a-1–4a-101 → title_04a.htm
# [CHECK] Chapter link covers 4a-1–4a-18 for Sec. 4a-67d..
# [CHECK] Chapter link covers 4a-19–4a-24 for Sec. 4a-67d..
# [CHECK] Chapter link covers 4a-25–4a-49 for Sec. 4a-67d..
# [CHECK] Chapter link covers 4a-50–4a-99 for Sec. 4a-67d..
# [FOUND] In‐chapter 4a-50–4a-99 → https://www.cga.ct.gov/current/pub/chap_058.htm
# [INFO] Extracting sec_4a-67d…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-13a..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-13a…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-15a..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-15a…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-16..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-16…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-17..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-17…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-21..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-21…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-23..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-23…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-31..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-31…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-47..
# [FOUND] In‐chapter 4b-1–4b-50 → https://www.cga.ct.gov/current/pub/chap_059.htm
# [INFO] Extracting sec_4b-47…
# [MATCH] Top‐level range 4b-1–4b-136 → title_04b.htm
# [CHECK] Chapter link covers 4b-1–4b-50 for Sec. 4b-51..
# [CHECK] Chapter link covers 4b-51–4b-129 for Sec. 4b-51..
# [FOUND] In‐chapter 4b-51–4b-129 → https://www.cga.ct.gov/current/pub/chap_060.htm
# [INFO] Extracting sec_4b-51…
# [MATCH] Top‐level range 4d-1–4d-100 → title_04d.htm
# [CHECK] Chapter link covers 4d-1–4d-79 for Sec. 4d-92..
# [CHECK] Chapter link covers 4d-80–4d-89 for Sec. 4d-92..
# [CHECK] Chapter link covers 4d-90–4d-99 for Sec. 4d-92..
# [FOUND] In‐chapter 4d-90–4d-99 → https://www.cga.ct.gov/current/pub/chap_061b.htm
# [INFO] Extracting sec_4d-92…
# [MATCH] Top‐level range 5-1–5-280 → title_05.htm
# [CHECK] Chapter link covers 5-1–5-93b for Sec. 5-142..
# [CHECK] Chapter link covers 5-94–5-141 for Sec. 5-142..
# [CHECK] Chapter link covers 5-141a–5-141e for Sec. 5-142..
# [CHECK] Chapter link covers 5-142–5-151 for Sec. 5-142..
# [FOUND] In‐chapter 5-142–5-151 → https://www.cga.ct.gov/current/pub/chap_065.htm
# [INFO] Extracting sec_5-142…
# [MATCH] Top‐level range 5-1–5-280 → title_05.htm
# [CHECK] Chapter link covers 5-1–5-93b for Sec. 5-238a..
# [CHECK] Chapter link covers 5-94–5-141 for Sec. 5-238a..
# [CHECK] Chapter link covers 5-141a–5-141e for Sec. 5-238a..
# [CHECK] Chapter link covers 5-142–5-151 for Sec. 5-238a..
# [CHECK] Chapter link covers 5-152–5-192mm for Sec. 5-238a..
# [CHECK] Chapter link covers 5-192nn–5-192nn for Sec. 5-238a..
# [CHECK] Chapter link covers 5-193–5-269 for Sec. 5-238a..
# [FOUND] In‐chapter 5-193–5-269 → https://www.cga.ct.gov/current/pub/chap_067.htm
# [INFO] Extracting sec_5-238a…
# Future exception was never retrieved
# future: <Future finished exception=TargetClosedError('Target page, context or browser has been closed')>
# playwright._impl._errors.TargetClosedError: Target page, context or browser has been closed
# C:\Users\zdgen\anaconda3\Lib\site-packages\pyee\base.py:186: RuntimeWarning: coroutine 'ElementHandle.inner_text' was never awaited
#   funcs = list(self._events.get(event, OrderedDict()).values())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-121d..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-121d..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-121d..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-121d..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-121d..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-121d..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-121d..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-121d..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-121d..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-121d..
# [FOUND] In‐chapter 7-101–7-147 → https://www.cga.ct.gov/current/pub/chap_097.htm
# [INFO] Extracting sec_7-121d…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-121f..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-121f..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-121f..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-121f..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-121f..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-121f..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-121f..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-121f..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-121f..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-121f..
# [FOUND] In‐chapter 7-101–7-147 → https://www.cga.ct.gov/current/pub/chap_097.htm
# [INFO] Extracting sec_7-121f…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-121n..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-121n..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-121n..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-121n..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-121n..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-121n..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-121n..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-121n..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-121n..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-121n..
# [FOUND] In‐chapter 7-101–7-147 → https://www.cga.ct.gov/current/pub/chap_097.htm
# [INFO] Extracting sec_7-121n…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-131..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-131..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-131..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-131..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-131..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-131..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-131..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-131..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-131..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-131..
# [FOUND] In‐chapter 7-101–7-147 → https://www.cga.ct.gov/current/pub/chap_097.htm
# [INFO] Extracting sec_7-131…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-131a..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-131a..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-131a..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-131a..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-131a..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-131a..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-131a..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-131a..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-131a..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-131a..
# [FOUND] In‐chapter 7-101–7-147 → https://www.cga.ct.gov/current/pub/chap_097.htm
# [INFO] Extracting sec_7-131a…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-131d..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-131d..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-131d..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-131d..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-131d..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-131d..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-131d..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-131d..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7

# [CHECK] Chapter link covers 7-148–7-186q for Sec. 7-217..
# [CHECK] Chapter link covers 7-187–7-201 for Sec. 7-217..
# [CHECK] Chapter link covers 7-202–7-212a for Sec. 7-217..
# [CHECK] Chapter link covers 7-213–7-233 for Sec. 7-217..
# [FOUND] In‐chapter 7-213–7-233 → https://www.cga.ct.gov/current/pub/chap_101.htm
# [INFO] Extracting sec_7-217…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-217a..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-217a..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-217a..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-217a..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-217a..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-217a..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-217a..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-217a..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-217a..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-217a..
# [CHECK] Chapter link covers 7-147a–7-147y for Sec. 7-217a..
# [CHECK] Chapter link covers 7-148–7-186q for Sec. 7-217a..
# [CHECK] Chapter link covers 7-187–7-201 for Sec. 7-217a..
# [CHECK] Chapter link covers 7-202–7-212a for Sec. 7-217a..
# [CHECK] Chapter link covers 7-213–7-233 for Sec. 7-217a..
# [FOUND] In‐chapter 7-213–7-233 → https://www.cga.ct.gov/current/pub/chap_101.htm
# [INFO] Extracting sec_7-217a…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-222..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-222..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-222..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-222..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-222..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-222..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-222..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-222..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-222..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-222..
# [CHECK] Chapter link covers 7-147a–7-147y for Sec. 7-222..
# [CHECK] Chapter link covers 7-148–7-186q for Sec. 7-222..
# [CHECK] Chapter link covers 7-187–7-201 for Sec. 7-222..
# [CHECK] Chapter link covers 7-202–7-212a for Sec. 7-222..
# [CHECK] Chapter link covers 7-213–7-233 for Sec. 7-222..
# [FOUND] In‐chapter 7-213–7-233 → https://www.cga.ct.gov/current/pub/chap_101.htm
# [INFO] Extracting sec_7-222…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-222a..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-222a..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-222a..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-222a..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-222a..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-222a..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-222a..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-222a..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-222a..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-222a..
# [CHECK] Chapter link covers 7-147a–7-147y for Sec. 7-222a..
# [CHECK] Chapter link covers 7-148–7-186q for Sec. 7-222a..
# [CHECK] Chapter link covers 7-187–7-201 for Sec. 7-222a..
# [CHECK] Chapter link covers 7-202–7-212a for Sec. 7-222a..
# [CHECK] Chapter link covers 7-213–7-233 for Sec. 7-222a..
# [FOUND] In‐chapter 7-213–7-233 → https://www.cga.ct.gov/current/pub/chap_101.htm
# [INFO] Extracting sec_7-222a…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-233b..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-233b..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-233b..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-233b..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-233b..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-233b..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-233b..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-233b..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-233b..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-233b..
# [CHECK] Chapter link covers 7-147a–7-147y for Sec. 7-233b..
# [CHECK] Chapter link covers 7-148–7-186q for Sec. 7-233b..
# [CHECK] Chapter link covers 7-187–7-201 for Sec. 7-233b..
# [CHECK] Chapter link covers 7-202–7-212a for Sec. 7-233b..
# [CHECK] Chapter link covers 7-213–7-233 for Sec. 7-233b..
# [CHECK] Chapter link covers 7-233a–7-233hh for Sec. 7-233b..
# [FOUND] In‐chapter 7-233a–7-233hh → https://www.cga.ct.gov/current/pub/chap_101a.htm
# [INFO] Extracting sec_7-233b…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-233c..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-233c..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7-233c..
# [CHECK] Chapter link covers 7-35aa–7-35gg for Sec. 7-233c..
# [CHECK] Chapter link covers 7-36–7-78 for Sec. 7-233c..
# [CHECK] Chapter link covers 7-79–7-85 for Sec. 7-233c..
# [CHECK] Chapter link covers 7-86–7-97 for Sec. 7-233c..
# [CHECK] Chapter link covers 7-98–7-100j for Sec. 7-233c..
# [CHECK] Chapter link covers 7-100k–7-100z for Sec. 7-233c..
# [CHECK] Chapter link covers 7-101–7-147 for Sec. 7-233c..
# [CHECK] Chapter link covers 7-147a–7-147y for Sec. 7-233c..
# [CHECK] Chapter link covers 7-148–7-186q for Sec. 7-233c..
# [CHECK] Chapter link covers 7-187–7-201 for Sec. 7-233c..
# [CHECK] Chapter link covers 7-202–7-212a for Sec. 7-233c..
# [CHECK] Chapter link covers 7-213–7-233 for Sec. 7-233c..
# [CHECK] Chapter link covers 7-233a–7-233hh for Sec. 7-233c..
# [FOUND] In‐chapter 7-233a–7-233hh → https://www.cga.ct.gov/current/pub/chap_101a.htm
# [INFO] Extracting sec_7-233c…
# [MATCH] Top‐level range 7-1–7-623 → title_07.htm
# [CHECK] Chapter link covers 7-1–7-9d for Sec. 7-233d..
# [CHECK] Chapter link covers 7-10–7-15 for Sec. 7-233d..
# [CHECK] Chapter link covers 7-16–7-35z for Sec. 7

# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-50v..
# [FOUND] In‐chapter 16-50g–16-50zz → https://www.cga.ct.gov/current/pub/chap_277a.htm
# [INFO] Extracting sec_16-50v…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-50kk..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-50kk..
# [FOUND] In‐chapter 16-50g–16-50zz → https://www.cga.ct.gov/current/pub/chap_277a.htm
# [INFO] Extracting sec_16-50kk…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-50ll..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-50ll..
# [FOUND] In‐chapter 16-50g–16-50zz → https://www.cga.ct.gov/current/pub/chap_277a.htm
# [INFO] Extracting sec_16-50ll…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-50aaa..
# [FOUND] In‐chapter 16-1–16-50f → https://www.cga.ct.gov/current/pub/chap_277.htm
# [INFO] Extracting sec_16-50aaa…
# [ERROR] Failed to extract sec_16-50aaa: Page.eval_on_selector: Failed to find element matching selector "span#sec_16-50aaa"
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-50bbb..
# [FOUND] In‐chapter 16-1–16-50f → https://www.cga.ct.gov/current/pub/chap_277.htm
# [INFO] Extracting sec_16-50bbb…
# [ERROR] Failed to extract sec_16-50bbb: Page.eval_on_selector: Failed to find element matching selector "span#sec_16-50bbb"
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-234..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-234..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-234..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-234..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-234..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-234..
# [CHECK] Chapter link covers 16-191–16-215 for Sec. 16-234..
# [CHECK] Chapter link covers 16-216–16-227 for Sec. 16-234..
# [CHECK] Chapter link covers 16-228–16-262aa for Sec. 16-234..
# [FOUND] In‐chapter 16-228–16-262aa → https://www.cga.ct.gov/current/pub/chap_283.htm
# [INFO] Extracting sec_16-234…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-243a..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-243a..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-243a..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-243a..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-243a..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-243a..
# [CHECK] Chapter link covers 16-191–16-215 for Sec. 16-243a..
# [CHECK] Chapter link covers 16-216–16-227 for Sec. 16-243a..
# [CHECK] Chapter link covers 16-228–16-262aa for Sec. 16-243a..
# [FOUND] In‐chapter 16-228–16-262aa → https://www.cga.ct.gov/current/pub/chap_283.htm
# [INFO] Extracting sec_16-243a…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-243b..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-243b..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-243b..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-243b..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-243b..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-243b..
# [CHECK] Chapter link covers 16-191–16-215 for Sec. 16-243b..
# [CHECK] Chapter link covers 16-216–16-227 for Sec. 16-243b..
# [CHECK] Chapter link covers 16-228–16-262aa for Sec. 16-243b..
# [FOUND] In‐chapter 16-228–16-262aa → https://www.cga.ct.gov/current/pub/chap_283.htm
# [INFO] Extracting sec_16-243b…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-243c..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-243c..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-243c..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-243c..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-243c..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-243c..
# [CHECK] Chapter link covers 16-191–16-215 for Sec. 16-243c..
# [CHECK] Chapter link covers 16-216–16-227 for Sec. 16-243c..
# [CHECK] Chapter link covers 16-228–16-262aa for Sec. 16-243c..
# [FOUND] In‐chapter 16-228–16-262aa → https://www.cga.ct.gov/current/pub/chap_283.htm
# [INFO] Extracting sec_16-243c…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-243f..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-243f..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-243f..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-243f..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-243f..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-243f..
# [CHECK] Chapter link covers 16-191–16-215 for Sec. 16-243f..
# [CHECK] Chapter link covers 16-216–16-227 for Sec. 16-243f..
# [CHECK] Chapter link covers 16-228–16-262aa for Sec. 16-243f..
# [FOUND] In‐chapter 16-228–16-262aa → https://www.cga.ct.gov/current/pub/chap_283.htm
# [INFO] Extracting sec_16-243f…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-243g..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-243g..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-243g..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-243g..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-243g..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-243g..
# [CHECK] Chapter link covers 16-191–16-215 for Sec. 16-243g..
# [CHECK] Chapter link covers 16-216–16-227 for Sec. 16-243g..
# [CHECK] Chapter link covers 16-228–16-262aa for Sec. 16-243g..
# [FOUND] In‐chapter 16-228–16-262aa → https://www.cga.ct.gov/current/pub/chap_283.htm
# [INFO] Extracting sec_16-243g…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-243h..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-243h..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-243h..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-243h..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-243h..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-243h..
# [CHECK] Chapter link covers 16-191–16-215 for Sec. 16-243h..
# [CHECK] Chapter link covers 16-216–16-227 for Sec. 16-243h..
# [CHECK] Chapter link covers 16-228–16-262aa for Sec. 16-243h..
# [FOUND] In‐chapter 16-228–16-262aa → https://www.cga.ct.gov/current/pub/chap_283.htm
# [INFO] Extracting sec_16-243h…
# [MATCH] Top‐level range 16-1–16-359 → title_16.htm
# [CHECK] Chapter link covers 16-1–16-50f for Sec. 16-243k..
# [CHECK] Chapter link covers 16-50g–16-50zz for Sec. 16-243k..
# [CHECK] Chapter link covers 16-50aaa–16-50bbb for Sec. 16-243k..
# [CHECK] Chapter link covers 16-51–16-75i for Sec. 16-243k..
# [CHECK] Chapter link covers 16-76–16-139a for Sec. 16-243k..
# [CHECK] Chapter link covers 16-140–16-190 for Sec. 16-243k..
